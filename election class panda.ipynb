# %%
import pandas as pd
from pandas import DataFrame, Series
data =pd.read_csv('Election data 2018.csv')
data
# Out:
#      District                     Seat Constituency_title  \
# 0     Chitral                  Chitral               NA-1
# 1     Chitral                  Chitral               NA-1
# 2     Chitral                  Chitral               NA-1
# 3     Chitral                  Chitral               NA-1
# 4     Chitral                  Chitral               NA-1
# 5     Chitral                  Chitral               NA-1
# 6     Chitral                  Chitral               NA-1
# 7     Chitral                  Chitral               NA-1
# 8     Chitral                  Chitral               NA-1
# 9     Chitral                  Chitral               NA-1
# 10    Chitral                  Chitral               NA-1
# 11       Swat                   Swat-I              NA-2
# 12       Swat                   Swat-I              NA-2
# 13       Swat                   Swat-I              NA-2
# 14       Swat                   Swat-I              NA-2
# ...

# %%
data[data['Party']=='Pakistan Tehreek-e-lnsaf']
# Out:
#                    District                Seat Constituency_title  \
# 5                   Chitral             Chitral               NA-1
# 13                     Swat              Swat-I              NA-2
# 23                     Swat             Swat-II               NA-3
# 39                     Swat            Swat-III               NA-4
# 43                Upper Dir           Upper Dir               NA-5
# 56                Lower Dir         Lower Dir-I               NA-6
# 63                Lower Dir        Lower Dir-II               NA-7
# 69                 Malakand            Malakand               NA-8
# 136  Mnnsehra? culn Torghar             Torghar             NA- 14
# 152            Abbottabad-1        Abbottabad-1              NA-15
# 167            Abbottabad-2        Abbottabad-2              NA-16
# 184                 Haripur             Haripur              NA-17
# 259                Nowshera          Nowshera-2              NA-26
# ...

# %%
data[data['Party']=='Pakistan Peoples Party Parliamentarians']
# Out:
#                                        District  \
# 3                                       Chitral
# 11                                         Swat
# 25                                         Swat
# 35                                         Swat
# 49                                    Upper Dir
# 51                                    Lower Dir
# 60                                    Lower Dir
# 67                                     Malakand
# 110   Kohistan-cum-Lower\nKolai Pallas Kohistan
# 114                                   Battagram
# 151                                Abbottabad-1
# 209                                       Swabi
# 216                                      Mardan
# 872                                     Chakwal
# 893                                      Gujrat
# 916                                      Gujrat
# 922                                      Gujrat
# 937                                      Gujrat
# ...

# %%
data[(data['Party']=='Pakistan Peoples Party Parliamentarians') & (data['District']=='Chitral')]
# Out:
#   District     Seat Constituency_title Candidate_Name  \
# 3  Chitral  Chitral               NA-1    Saleem Khan
#
#                                      Party
# 3  Pakistan Peoples Party Parliamentarians

# %%
data[(data['Party']=='Pakistan Peoples Party Parliamentarians') & (data['District']=='Chitral')].count()
# Out:
# District              1
# Seat                  1
# Constituency_title    1
# Candidate_Name        1
# Party                 1
# dtype: int64

# %%
data[(data['Party']=='Pakistan Peoples Party Parliamentarians') ].count()
# Out:
# District              75
# Seat                  75
# Constituency_title    75
# Candidate_Name        75
# Party                 75
# dtype: int64

# %%
data[(data['Party']=='Pakistan Peoples Party Parliamentarians')][2:50]
# Out:
#                                        District  \
# 25                                         Swat
# 35                                         Swat
# 49                                    Upper Dir
# 51                                    Lower Dir
# 60                                    Lower Dir
# 67                                     Malakand
# 110   Kohistan-cum-Lower\nKolai Pallas Kohistan
# 114                                   Battagram
# 151                                Abbottabad-1
# 209                                       Swabi
# 216                                      Mardan
# 872                                     Chakwal
# 893                                      Gujrat
# 916                                      Gujrat
# 922                                      Gujrat
# 937                                      Gujrat
# 943                                     Sialkot
# 954                                     Sialkot
# ...

# %%
data[(data['Party']=='Pakistan Peoples Party Parliamentarians') ].tail()
# Out:
#      District                     Seat Constituency_title  \
# 3071  Mastung      Mastung-cum-Shaheed             NA-267
# 3093   Chagai  Chagai-cum-Nushki-sum-K             NA-268
# 3114  Khuzdar                  Khuzdar             NA-269
# 3128  Panjgur  Panjgur-cum-Washuk-cum-             NA-270
# 3140     Kech                     Kech             NA-271
#
#                          Candidate_Name  \
# 3071                   AyatUllah Durani
# 3093  Sardar Alhaj Muhmmad Umer Gorgage
# 3114                      Adbdul Raheem
# 3128                   Sabir Ali Baloch
# 3140                        Barkat Ali
#
#                                         Party
# 3071  Pakistan Peoples Party Parliamentarians
# 3093  Pakistan Peoples Party Parliamentarians
# 3114  Pakistan Peoples Party Parliamentarians
# 3128  Pakistan Peoples Party Parliamentarians
# 3140  Pakistan Peoples Party Parliamentarians

# %%
data[(data['Constituency_title']=='NA-1') ]
# Out:
#    District     Seat Constituency_title                     Candidate_Name  \
# 0   Chitral  Chitral               NA-1                   lftikhar ud Din
# 1   Chitral  Chitral               NA-1                      Taqdira Ajmal
# 2   Chitral  Chitral               NA-1                    Saeed Ur Rehman
# 3   Chitral  Chitral               NA-1                        Saleem Khan
# 4   Chitral  Chitral               NA-1  Shahzada Muharamad Taimur Khisrao
# 5   Chitral  Chitral               NA-1                        Abdul Latif
# 6   Chitral  Chitral               NA-1                      Eid ulHussain
# 7   Chitral  Chitral               NA-1                     Mohammad Amjad
# 8   Chitral  Chitral               NA-1                     Muhammad Yahya
# 9   Chitral  Chitral               NA-1       Moulana Abdul Akbar Chitrali
# 10  Chitral  Chitral               NA-1                     Nisar Dastager
#
#                                       Party
# ...

# %%
data['Constituency_title']
# Out:
# 3167

# %%
data.shape
# Out:
# (3167, 5)

# %%
data.columns
# Out:
# Index(['District', 'Seat', 'Constituency_title', 'Candidate_Name', 'Party'], dtype='object')

# %%
data.groupby(['Constituency_title']).count() # sort my show karta ha but string issue ha or groupby ka use same given columns  ko count karlyga
# Out:
#                     District  Seat  Candidate_Name  Party
# Constituency_title
#  NA-112                   14    14              14     14
#  NA-113                   17    17              17     17
# NA- 14                     3     3               3      3
# NA-1                      11    11              11     11
# NA-10                      9     9               9      9
# NA-100                    13    13              13     13
# NA-101                    14    14              14     14
# NA-102                    16    16              16     16
# NA-103                    10    10              10     10
# NA-104                    14    14              14     14
# NA-105                    13    13              13     13
# NA-106                     8     8               8      8
# NA-107                     7     7               7      7
# NA-108                     8     8               8      8
# NA-109                    10    10              10     10
# ...

# %%
data.groupby(['Constituency_title']).max()count()
# Out:
# District          250
# Seat              250
# Candidate_Name    250
# Party             250
# dtype: int64

# %%
data.groupby('Constituency_title').count().max()
# Out:
# District          39
# Seat              39
# Candidate_Name    39
# Party             39
# dtype: int64

# %%
data.groupby('Constituency_title')['Party'].count().nlargest(6)
# Out:
# Constituency_title
# NA-45     39
# NA-48     35
# NA-53     33
# NA-259    31
# NA-50     28
# NA-54     28
# Name: Party, dtype: int64

# %%
data.groupby(['Party']).count()
# Out:
#                                          District  Seat  Constituency_title  \
# Party
#                                                 1     1                   1
# ALL PAKISTAN MUSLIM LEAGUE                      1     1                   1
# Aam Admi Tehreek Pakistan                       1     1                   1
# Aam Awam Party                                  2     2                   2
# Aam Log Party Pakistan                          4     4                   4
# All Pakistan Mishit) League                     1     1                   1
# All Pakistan Muslim League                     33    33                  33
# All Pakistan Muslim League                      6     6                   6
# All Pakistan Muslim League (Jinnah)             1     1                   1
# All Pakistan Muslim League(Jinnah)              1     1                   1
# All Pakistan Muslim league                      1     1                   1
# ...

# %%
data[data.Constituency_title=='NA-245'].count()
# Out:
# District              15
# Seat                  15
# Constituency_title    15
# Candidate_Name        15
# Party                 15
# dtype: int64

# %%
data[(data['Party']=='Pakistan Peoples Party Parliamentarians') ].count()
# Out:
# District              75
# Seat                  75
# Constituency_title    75
# Candidate_Name        75
# Party                 75
# dtype: int64

# %%
data[(data.Party=='Pakistan Peoples Party Parliamentarians') ].count()
# Out:
# District              75
# Seat                  75
# Constituency_title    75
# Candidate_Name        75
# Party                 75
# dtype: int64

# %%
#covarience : mean se niklygy value se given valye ka differ
#corelation : RELATION
#JSON my sara string double score my ""
# read section 6.3
#crypto campare parhna ha
